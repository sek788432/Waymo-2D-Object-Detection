# %% [markdown]
# # Preprocess

# %%
import glob
code_source = 'code/create_record_multifiles.py'
s_ind, e_ind = 0, 31
for i in range(s_ind, e_ind+1):
    target_dir = 'input/data_all_camera/valid_'+str(i)+'/processed'
    # !mkdir "$target_dir"
    for file in glob.glob('input/data_all_camera/valid_'+str(i)+'/*.tfrecord'):
        # !python "$code_source" --filepath="$file" --output_dir="$target_dir"
# Out:
# 2021-06-09 09:32:55.162264: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 09:32:57,198 INFO     Processing /target/waymo/input/data_all_camera/valid_0/segment-10359308928573410754_720_000_740_000_with_camera_labels.tfrecord
# 2021-06-09 09:32:57.199326: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-09 09:32:57.203584: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-06-09 09:32:57.215902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:32:57.216219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# ...
