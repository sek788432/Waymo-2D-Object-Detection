# %% [markdown]
# # Evaluate

# %%
# !python ../../code/model_main_tf2.py --model_dir=input/centernet_train_all_data\
              --pipeline_config_path=input/centernet_train_all_data/pipeline.config\
              --checkpoint_dir=input/centernet_train_all_data
# Out:
# 2021-06-13 09:19:23.371241: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-13 09:19:24.962787: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-13 09:19:24.963334: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-06-13 09:19:24.991085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-13 09:19:24.991358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 SUPER computeCapability: 7.5
# coreClock: 1.83GHz coreCount: 48 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 462.00GiB/s
# ...

# %% [markdown]
# # Export Model

# %%
# !python input/models/research/object_detection/exporter_main_v2.py \
    --input_type image_tensor \
    --pipeline_config_path input/centernet_train_all_data/pipeline.config\
    --trained_checkpoint_dir input/centernet_train_all_data\
    --output_directory output/exported-models/centernet_train_all_data_81ckpt
# Out:
# 2021-06-13 08:30:17.289812: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-13 08:30:18.859156: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-13 08:30:18.859677: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-06-13 08:30:18.890816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-13 08:30:18.891073: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 SUPER computeCapability: 7.5
# coreClock: 1.83GHz coreCount: 48 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 462.00GiB/s
# ...

# %% [markdown]
# # Predict Images
# ## Run waymo and test image

# %%
# !python code/detect.py --saved_model_path=output/exported-models/centernet_train_all_data_81ckpt\
          --test_path=input/test_image\
          --output_path=output/centernet_train_all_data_81ckpt_0.4threshold/test_image/output_image\
          --min_score_thresh=0.4
           
          # waymo_test_image-001
          # test_image
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING:absl:Importing a function (__inference_bifpn_layer_call_and_return_conditional_losses_101314) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_bifpn_layer_call_and_return_conditional_losses_101314) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_bifpn_layer_call_and_return_conditional_losses_101314) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_bifpn_layer_call_and_return_conditional_losses_101314) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_bifpn_layer_call_and_return_conditional_losses_101314) with ops with custom gradients. Will likely fail if a gradient is requested.
# ...
