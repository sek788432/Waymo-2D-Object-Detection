# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.0

# %%
# !python code/model_main_tf2.py --model_dir=input/centernet_train_all_data\
                          --pipeline_config_path=input/centernet_train_all_data/pipeline.config
# Out:
# 2021-06-09 12:59:31.461972: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 12:59:33.235030: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-09 12:59:33.235569: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-06-09 12:59:33.258152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.258383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 SUPER computeCapability: 7.5
# coreClock: 1.83GHz coreCount: 48 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 462.00GiB/s
# 2021-06-09 12:59:33.258397: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 12:59:33.259887: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-06-09 12:59:33.259919: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-06-09 12:59:33.260539: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-06-09 12:59:33.260674: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-06-09 12:59:33.262229: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-06-09 12:59:33.262609: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-06-09 12:59:33.262703: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-06-09 12:59:33.262771: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.263039: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.263293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2021-06-09 12:59:33.264403: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-09 12:59:33.264505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.264788: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 SUPER computeCapability: 7.5
# coreClock: 1.83GHz coreCount: 48 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 462.00GiB/s
# 2021-06-09 12:59:33.264800: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 12:59:33.264830: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-06-09 12:59:33.264841: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-06-09 12:59:33.264852: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-06-09 12:59:33.264862: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-06-09 12:59:33.264888: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-06-09 12:59:33.264897: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-06-09 12:59:33.264907: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-06-09 12:59:33.264964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.265244: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.265467: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-06-09 12:59:33.265483: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 12:59:33.593361: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-09 12:59:33.593413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-06-09 12:59:33.593418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-06-09 12:59:33.593599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.593927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.594256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 12:59:33.594531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6909 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 SUPER, pci bus id: 0000:02:00.0, compute capability: 7.5)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0609 12:59:33.596025 140583318472512 mirrored_strategy.py:350] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0609 12:59:33.599928 140583318472512 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0609 12:59:33.600101 140583318472512 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/model_lib_v2.py:558: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0609 12:59:33.693724 140583318472512 deprecation.py:339] From /usr/local/lib/python3.6/dist-packages/object_detection/model_lib_v2.py:558: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/target/waymo/input/data_all_camera/train_0/processed/*.tfrecord']
# I0609 12:59:33.696421 140583318472512 dataset_builder.py:163] Reading unweighted datasets: ['/target/waymo/input/data_all_camera/train_0/processed/*.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/target/waymo/input/data_all_camera/train_0/processed/*.tfrecord']
# I0609 12:59:33.722692 140583318472512 dataset_builder.py:80] Reading record datasets for input file: ['/target/waymo/input/data_all_camera/train_0/processed/*.tfrecord']
# INFO:tensorflow:Number of filenames to read: 44
# I0609 12:59:33.722804 140583318472512 dataset_builder.py:81] Number of filenames to read: 44
# WARNING:tensorflow:num_readers has been reduced to 44 to match input file shards.
# W0609 12:59:33.722901 140583318472512 dataset_builder.py:88] num_readers has been reduced to 44 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0609 12:59:33.724939 140583318472512 deprecation.py:339] From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0609 12:59:33.742231 140583318472512 deprecation.py:339] From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0609 12:59:39.490647 140583318472512 deprecation.py:339] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# ^C
# Traceback (most recent call last):
#   File "../../code/model_main_tf2.py", line 119, in <module>
#     tf.compat.v1.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "../../code/model_main_tf2.py", line 116, in main
#     record_summaries=FLAGS.record_summaries)
#   File "/usr/local/lib/python3.6/dist-packages/object_detection/model_lib_v2.py", line 558, in train_loop
#     train_dataset_fn)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py", line 340, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py", line 1143, in experimental_distribute_datasets_from_function
#     return self.distribute_datasets_from_function(dataset_fn, options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py", line 1135, in distribute_datasets_from_function
#     dataset_fn, options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/mirrored_strategy.py", line 547, in _distribute_datasets_from_function
#     options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/input_lib.py", line 162, in get_distributed_datasets_from_function
#     input_contexts, strategy, options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/input_lib.py", line 1273, in __init__
#     self._input_contexts, self._input_workers, dataset_fn))
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/input_lib.py", line 1936, in _create_datasets_from_function_with_input_context
#     dataset = dataset_fn(ctx)
#   File "/usr/local/lib/python3.6/dist-packages/object_detection/model_lib_v2.py", line 553, in train_dataset_fn
#     input_context=input_context)
#   File "/usr/local/lib/python3.6/dist-packages/object_detection/inputs.py", line 906, in train_input
#     reduce_to_frame_fn=reduce_to_frame_fn)
#   File "/usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py", line 258, in build
#     batch_size, input_reader_config)
#   File "/usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py", line 237, in dataset_map_fn
#     fn_to_map, num_parallel_calls=num_parallel_calls)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py", line 340, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 2685, in map_with_legacy_function
#     use_legacy_function=True))
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 4246, in __init__
#     use_legacy_function=use_legacy_function)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 3493, in __init__
#     self._function.add_to_graph(ops.get_default_graph())
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/function.py", line 546, in add_to_graph
#     self._create_definition_if_needed()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/function.py", line 378, in _create_definition_if_needed
#     self._create_definition_if_needed_impl()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/function.py", line 409, in _create_definition_if_needed_impl
#     capture_resource_var_by_value=self._capture_resource_var_by_value)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/function.py", line 971, in func_graph_from_py_func
#     outputs = func(*func_graph.inputs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 3485, in wrapper_fn
#     ret = _wrapper_helper(*args)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 3453, in _wrapper_helper
#     ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 667, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmpx_v5gram.py", line 23, in tf__transform_and_pad_input_data_fn
#     tensor_dict = ag__.converted_call(ag__.ld(pad_input_data_to_static_shapes), (), dict(tensor_dict=ag__.converted_call(ag__.ld(transform_data_fn), (ag__.ld(tensor_dict),), None, fscope), max_num_boxes=ag__.ld(train_input_config).max_number_of_boxes, num_classes=ag__.ld(num_classes), spatial_image_shape=ag__.converted_call(ag__.ld(config_util).get_spatial_image_size, (ag__.ld(image_resizer_config),), None, fscope), max_num_context_features=ag__.converted_call(ag__.ld(config_util).get_max_num_context_features, (ag__.ld(model_config),), None, fscope), context_feature_length=ag__.converted_call(ag__.ld(config_util).get_context_feature_length, (ag__.ld(model_config),), None, fscope)), fscope)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 376, in converted_call
#     options=options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmp86ye65p2.py", line 143, in tf__transform_input_data
#     ag__.if_stmt((ag__.ld(data_augmentation_fn) is not None), if_body_7, else_body_7, get_state_8, set_state_8, ('out_tensor_dict',), 1)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 1165, in if_stmt
#     _py_if_stmt(cond, body, orelse)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 1218, in _py_if_stmt
#     return body() if cond else orelse()
#   File "/tmp/tmp86ye65p2.py", line 138, in if_body_7
#     out_tensor_dict = ag__.converted_call(ag__.ld(data_augmentation_fn), (ag__.ld(out_tensor_dict),), None, fscope)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 376, in converted_call
#     options=options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmpegp9f20g.py", line 23, in tf__augment_input_data
#     tensor_dict = ag__.converted_call(ag__.ld(preprocessor).preprocess, (ag__.ld(tensor_dict), ag__.ld(data_augmentation_options)), dict(func_arg_map=ag__.converted_call(ag__.ld(preprocessor).get_default_func_arg_map, (), dict(include_label_weights=ag__.ld(include_label_weights), include_label_confidences=ag__.ld(include_label_confidences), include_multiclass_scores=ag__.ld(include_multiclass_scores), include_instance_masks=ag__.ld(include_instance_masks), include_instance_mask_weights=ag__.ld(include_instance_mask_weights), include_keypoints=ag__.ld(include_keypoints), include_keypoint_visibilities=ag__.ld(include_keypoint_visibilities), include_dense_pose=ag__.ld(include_dense_pose), include_keypoint_depths=ag__.ld(include_keypoint_depths)), fscope)), fscope)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmp1m48j0ap.py", line 200, in tf__preprocess
#     ag__.for_stmt(ag__.ld(preprocess_options), None, loop_body_2, get_state_11, set_state_11, (), {'iterate_names': 'option'})
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 444, in for_stmt
#     _py_for_stmt(iter_, extra_test, body, None, None)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 473, in _py_for_stmt
#     body(target)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 459, in protected_body
#     original_body(protected_iter)
#   File "/tmp/tmp1m48j0ap.py", line 160, in loop_body_2
#     results = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(params)), fscope)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmpj4l316rx.py", line 152, in tf__random_crop_image
#     ag__.if_stmt((ag__.ld(random_coef) < ag__.ld(sys).float_info.min), if_body_8, else_body_8, get_state_8, set_state_8, ('result',), 1)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 1165, in if_stmt
#     _py_if_stmt(cond, body, orelse)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 1218, in _py_if_stmt
#     return body() if cond else orelse()
#   File "/tmp/tmpj4l316rx.py", line 35, in if_body_8
#     result = ag__.converted_call(ag__.ld(strict_random_crop_image_fn), (), None, fscope)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 358, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 479, in _call_unconverted
#     return f(*args)
#   File "/tmp/tmpj4l316rx.py", line 20, in strict_random_crop_image_fn
#     retval__1 = ag__.converted_call(ag__.ld(_strict_random_crop_image), (ag__.ld(image), ag__.ld(boxes), ag__.ld(labels), ag__.ld(label_weights)), dict(label_confidences=ag__.ld(label_confidences), multiclass_scores=ag__.ld(multiclass_scores), masks=ag__.ld(masks), mask_weights=ag__.ld(mask_weights), keypoints=ag__.ld(keypoints), keypoint_visibilities=ag__.ld(keypoint_visibilities), densepose_num_points=ag__.ld(densepose_num_points), densepose_part_ids=ag__.ld(densepose_part_ids), densepose_surface_coords=ag__.ld(densepose_surface_coords), min_object_covered=ag__.ld(min_object_covered), aspect_ratio_range=ag__.ld(aspect_ratio_range), area_range=ag__.ld(area_range), overlap_thresh=ag__.ld(overlap_thresh), clip_boxes=ag__.ld(clip_boxes), preprocess_vars_cache=ag__.ld(preprocess_vars_cache)), fscope_1)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 447, in converted_call
#     converted_f = _convert_actual(target_entity, program_ctx)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 284, in _convert_actual
#     transformed, module, source_map = _TRANSPILER.transform(entity, program_ctx)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/transpiler.py", line 286, in transform
#     return self.transform_function(obj, user_context)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/transpiler.py", line 470, in transform_function
#     nodes, ctx = super(PyToPy, self).transform_function(fn, user_context)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/transpiler.py", line 363, in transform_function
#     result = self.transform_ast(node, context)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py", line 268, in transform_ast
#     node = control_flow.transform(node, ctx)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/converters/control_flow.py", line 412, in transform
#     node = reaching_definitions.resolve(node, ctx, graphs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/static_analysis/reaching_definitions.py", line 291, in resolve
#     node = visitor.visit(node)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/static_analysis/reaching_definitions.py", line 273, in visit
#     node = super(TreeAnnotator, self).visit(node)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/transformer.py", line 445, in visit
#     result = super(Base, self).visit(node)
#   File "/usr/lib/python3.6/ast.py", line 253, in visit
#     return visitor(node)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/static_analysis/reaching_definitions.py", line 194, in visit_FunctionDef
#     analyzer.visit_forward()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/cfg.py", line 246, in visit_forward
#     self._visit_internal(_WalkMode.FORWARD)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/cfg.py", line 234, in _visit_internal
#     should_revisit = self.visit_node(node)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/static_analysis/reaching_definitions.py", line 154, in visit_node
#     defs_out = gen | (defs_in - kill)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/static_analysis/reaching_definitions.py", line 98, in __or__
#     result.value[s] = set(other_infos)
# KeyboardInterrupt
